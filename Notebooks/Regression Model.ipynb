# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
import tensorflow as tf
from tensorflow.keras import models, layers, utils, optimizers, callbacks
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
from numpy.random import seed
seed(1)

# %%
dataset=pd.read_csv("Data/testset.csv")
dataset
# Out:
#          datetime_utc          _conds  _dewptm  _fog  _hail  _heatindexm  \
# 0      19961101-11:00           Smoke      9.0     0      0          NaN
# 1      19961101-12:00           Smoke     10.0     0      0          NaN
# 2      19961101-13:00           Smoke     11.0     0      0          NaN
# 3      19961101-14:00           Smoke     10.0     0      0          NaN
# 4      19961101-16:00           Smoke     11.0     0      0          NaN
# ...               ...             ...      ...   ...    ...          ...
# 99565  20161231-12:00   Partly Cloudy     15.0     0      0          NaN
# 99566  20161231-13:00   Partly Cloudy     16.0     0      0          NaN
# 99567  20161231-15:00             NaN     13.0     0      0          NaN
# 99568  20161231-18:00  Patches of Fog     12.0     1      0          NaN
# 99569  20161231-21:00  Patches of Fog     12.0     1      0          NaN
#
#         _hum  _precipm  _pressurem  _rain  _snow  _tempm  _thunder  _tornado  \
# 0       27.0       NaN      1010.0      0      0    30.0         0         0
# 1       32.0       NaN     -9999.0      0      0    28.0         0         0
# 2       44.0       NaN     -9999.0      0      0    24.0         0         0
# 3       41.0       NaN      1010.0      0      0    24.0         0         0
# 4       47.0       NaN      1011.0      0      0    23.0         0         0
# ...      ...       ...         ...    ...    ...     ...       ...       ...
# 99565   77.0       NaN      1015.0      0      0    18.0         0         0
# 99566  100.0       NaN      1014.0      0      0    16.0         0         0
# 99567    NaN       NaN      1016.0      0      0     NaN         0         0
# 99568  100.0       NaN      1016.0      0      0    12.0         0         0
# 99569   99.0       NaN      1016.0      0      0    12.0         0         0
#
#        _vism  _wdird _wdire  _wgustm  _windchillm  _wspdm
# 0       5.00   280.0   West      NaN          NaN     7.4
# 1        NaN     0.0  North      NaN          NaN     NaN
# 2        NaN     0.0  North      NaN          NaN     NaN
# 3       2.00     0.0  North      NaN          NaN     NaN
# 4       1.20     0.0  North      NaN          NaN     0.0
# ...      ...     ...    ...      ...          ...     ...
# 99565   0.50   110.0    ESE      NaN          NaN     7.4
# 99566   0.80    90.0   East      NaN          NaN     3.7
# 99567   0.05    10.0  North      NaN          NaN    59.3
# 99568   0.50     NaN    NaN      NaN          NaN     0.0
# 99569   0.50     NaN    NaN      NaN          NaN     0.0
#
# [99570 rows x 20 columns]

# %%
dataset.columns=dataset.columns.str.replace("_","")
dataset.columns=dataset.columns.str.replace(" ","")
dataset.columns
# Out:
# Index(['datetimeutc', 'conds', 'dewptm', 'fog', 'hail', 'heatindexm', 'hum',
#        'precipm', 'pressurem', 'rain', 'snow', 'tempm', 'thunder', 'tornado',
#        'vism', 'wdird', 'wdire', 'wgustm', 'windchillm', 'wspdm'],
#       dtype='object')

# %%
print(dataset["conds"].value_counts())
# Out:
# Haze                             47003
# Smoke                            20551
# Mist                              9104
# Clear                             3129
# Widespread Dust                   2830
# Fog                               2656
# Scattered Clouds                  2197
# Partly Cloudy                     2070
# Shallow Fog                       1860
# Mostly Cloudy                     1520
# Light Rain                        1297
# Partial Fog                       1004
# Patches of Fog                     850
# Thunderstorms and Rain             471
# Heavy Fog                          418
# Light Drizzle                      410
# Rain                               394
# Unknown                            382
# Blowing Sand                       358
# Overcast                           313
# Thunderstorm                       190
# Light Thunderstorms and Rain       170
# Drizzle                            111
# Light Thunderstorm                  63
# Light Fog                           56
# Heavy Rain                          28
# Heavy Thunderstorms and Rain        20
# Thunderstorms with Hail             11
# Squalls                              6
# Light Sandstorm                      6
# Light Rain Showers                   5
# Light Haze                           4
# Volcanic Ash                         4
# Funnel Cloud                         2
# Rain Showers                         2
# Sandstorm                            2
# Heavy Thunderstorms with Hail        1
# Light Freezing Rain                  1
# Light Hail Showers                   1
# Name: conds, dtype: int64

# %%
dataset["conds"]=dataset["conds"].replace(["Widespread Dust","Blowing Sand","Sandstorm", "Volcanic Ash","Light Sandstorm"],"Dust")
dataset["conds"]=dataset["conds"].replace(["Fog", "Shallow Fog", "Partial Fog","Light Fog", "Mist", "Heavy Fog", "Light Haze","Patches of Fog"],"Fog")
dataset["conds"]=dataset["conds"].replace(["Scattered Clouds", "Partly Cloudy",  "Mostly Cloudy" ,"Overcast","Funnel Cloud"], "Cloudy")
dataset["conds"]=dataset["conds"].replace(["Light Rain", "Light Drizzle","Rain", "Drizzle", "Light Rain Showers","Drizzle" ,"Rain Showers"], "Rain")
dataset["conds"]=dataset["conds"].replace(["Thunderstorms with Hail", "Squalls","Light Hail Showers" ,"Light Freezing Rain","Heavy Thunderstorms with Hail", "Unknown"], "Others")
dataset["conds"]=dataset["conds"].replace(["Thunderstorms and Rain", "Light Thunderstorms and Rain","Light Thunderstorm" ,"Heavy Thunderstorms and Rain","Heavy Rain"], "Thunderstorm")

# %%
print(dataset["conds"].value_counts())
# Out:
# Haze            47003
# Smoke           20551
# Fog             15952
# Cloudy           6102
# Dust             3200
# Clear            3129
# Rain             2219
# Thunderstorm      942
# Others            402
# Name: conds, dtype: int64

# %%
le=LabelEncoder()
col="conds"
dataset[col]=dataset.apply(lambda x: le.fit_transform(dataset[col].astype(str)),axis=0,result_type='expand')
dataset["conds"]
# Out:
# 0        7
# 1        7
# 2        7
# 3        7
# 4        7
#         ..
# 99565    1
# 99566    1
# 99567    9
# 99568    3
# 99569    3
# Name: conds, Length: 99570, dtype: int64

# %%
dataset['pressurem'].replace('-9999.0',np.nan)
dataset.replace(0,np.nan)
dataset.isnull().sum()
# Out:
# datetimeutc        0
# conds              0
# dewptm           620
# fog                0
# hail               0
# heatindexm     70457
# hum              756
# precipm        99570
# pressurem        232
# rain               0
# snow               0
# tempm            672
# thunder            0
# tornado            0
# vism            4428
# wdird          14492
# wdire          14492
# wgustm         98507
# windchillm     98997
# wspdm           2358
# dtype: int64

# %%
dataset
# Out:
#           datetimeutc  conds  dewptm  fog  hail  heatindexm    hum  precipm  \
# 0      19961101-11:00      7     9.0    0     0         NaN   27.0      NaN
# 1      19961101-12:00      7    10.0    0     0         NaN   32.0      NaN
# 2      19961101-13:00      7    11.0    0     0         NaN   44.0      NaN
# 3      19961101-14:00      7    10.0    0     0         NaN   41.0      NaN
# 4      19961101-16:00      7    11.0    0     0         NaN   47.0      NaN
# ...               ...    ...     ...  ...   ...         ...    ...      ...
# 99565  20161231-12:00      1    15.0    0     0         NaN   77.0      NaN
# 99566  20161231-13:00      1    16.0    0     0         NaN  100.0      NaN
# 99567  20161231-15:00      9    13.0    0     0         NaN    NaN      NaN
# 99568  20161231-18:00      3    12.0    1     0         NaN  100.0      NaN
# 99569  20161231-21:00      3    12.0    1     0         NaN   99.0      NaN
#
#        pressurem  rain  snow  tempm  thunder  tornado  vism  wdird  wdire  \
# 0         1010.0     0     0   30.0        0        0  5.00  280.0   West
# 1        -9999.0     0     0   28.0        0        0   NaN    0.0  North
# 2        -9999.0     0     0   24.0        0        0   NaN    0.0  North
# 3         1010.0     0     0   24.0        0        0  2.00    0.0  North
# 4         1011.0     0     0   23.0        0        0  1.20    0.0  North
# ...          ...   ...   ...    ...      ...      ...   ...    ...    ...
# 99565     1015.0     0     0   18.0        0        0  0.50  110.0    ESE
# 99566     1014.0     0     0   16.0        0        0  0.80   90.0   East
# 99567     1016.0     0     0    NaN        0        0  0.05   10.0  North
# 99568     1016.0     0     0   12.0        0        0  0.50    NaN    NaN
# 99569     1016.0     0     0   12.0        0        0  0.50    NaN    NaN
#
#        wgustm  windchillm  wspdm
# 0         NaN         NaN    7.4
# 1         NaN         NaN    NaN
# 2         NaN         NaN    NaN
# 3         NaN         NaN    NaN
# 4         NaN         NaN    0.0
# ...       ...         ...    ...
# 99565     NaN         NaN    7.4
# 99566     NaN         NaN    3.7
# 99567     NaN         NaN   59.3
# 99568     NaN         NaN    0.0
# 99569     NaN         NaN    0.0
#
# [99570 rows x 20 columns]

# %%
hum_median=dataset["hum"].median()
dataset["hum"].fillna(hum_median,inplace=True)
pressurem_median=dataset["pressurem"].median()
dataset["pressurem"].fillna(pressurem_median,inplace=True)
wspdm_median=dataset["wspdm"].median()
dataset["wspdm"].fillna(wspdm_median,inplace=True)
tempm_median=dataset["tempm"].median()
dataset["tempm"].fillna(tempm_median,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# datetimeutc        0
# conds              0
# dewptm           620
# fog                0
# hail               0
# heatindexm     70457
# hum                0
# precipm        99570
# pressurem          0
# rain               0
# snow               0
# tempm              0
# thunder            0
# tornado            0
# vism            4428
# wdird          14492
# wdire          14492
# wgustm         98507
# windchillm     98997
# wspdm              0
# dtype: int64

# %%
dataset
# Out:
#           datetimeutc  conds  dewptm  fog  hail  heatindexm    hum  precipm  \
# 0      19961101-11:00      7     9.0    0     0         NaN   27.0      NaN
# 1      19961101-12:00      7    10.0    0     0         NaN   32.0      NaN
# 2      19961101-13:00      7    11.0    0     0         NaN   44.0      NaN
# 3      19961101-14:00      7    10.0    0     0         NaN   41.0      NaN
# 4      19961101-16:00      7    11.0    0     0         NaN   47.0      NaN
# ...               ...    ...     ...  ...   ...         ...    ...      ...
# 99565  20161231-12:00      1    15.0    0     0         NaN   77.0      NaN
# 99566  20161231-13:00      1    16.0    0     0         NaN  100.0      NaN
# 99567  20161231-15:00      9    13.0    0     0         NaN   58.0      NaN
# 99568  20161231-18:00      3    12.0    1     0         NaN  100.0      NaN
# 99569  20161231-21:00      3    12.0    1     0         NaN   99.0      NaN
#
#        pressurem  rain  snow  tempm  thunder  tornado  vism  wdird  wdire  \
# 0         1010.0     0     0   30.0        0        0  5.00  280.0   West
# 1        -9999.0     0     0   28.0        0        0   NaN    0.0  North
# 2        -9999.0     0     0   24.0        0        0   NaN    0.0  North
# 3         1010.0     0     0   24.0        0        0  2.00    0.0  North
# 4         1011.0     0     0   23.0        0        0  1.20    0.0  North
# ...          ...   ...   ...    ...      ...      ...   ...    ...    ...
# 99565     1015.0     0     0   18.0        0        0  0.50  110.0    ESE
# 99566     1014.0     0     0   16.0        0        0  0.80   90.0   East
# 99567     1016.0     0     0   27.0        0        0  0.05   10.0  North
# 99568     1016.0     0     0   12.0        0        0  0.50    NaN    NaN
# 99569     1016.0     0     0   12.0        0        0  0.50    NaN    NaN
#
#        wgustm  windchillm  wspdm
# 0         NaN         NaN    7.4
# 1         NaN         NaN    7.4
# 2         NaN         NaN    7.4
# 3         NaN         NaN    7.4
# 4         NaN         NaN    0.0
# ...       ...         ...    ...
# 99565     NaN         NaN    7.4
# 99566     NaN         NaN    3.7
# 99567     NaN         NaN   59.3
# 99568     NaN         NaN    0.0
# 99569     NaN         NaN    0.0
#
# [99570 rows x 20 columns]

# %%
dataset_regression=dataset[['datetimeutc','hum','tempm','pressurem','wspdm']]

# %%
dataset_regression
# Out:
#           datetimeutc    hum  tempm  pressurem  wspdm
# 0      19961101-11:00   27.0   30.0     1010.0    7.4
# 1      19961101-12:00   32.0   28.0    -9999.0    7.4
# 2      19961101-13:00   44.0   24.0    -9999.0    7.4
# 3      19961101-14:00   41.0   24.0     1010.0    7.4
# 4      19961101-16:00   47.0   23.0     1011.0    0.0
# ...               ...    ...    ...        ...    ...
# 99565  20161231-12:00   77.0   18.0     1015.0    7.4
# 99566  20161231-13:00  100.0   16.0     1014.0    3.7
# 99567  20161231-15:00   58.0   27.0     1016.0   59.3
# 99568  20161231-18:00  100.0   12.0     1016.0    0.0
# 99569  20161231-21:00   99.0   12.0     1016.0    0.0
#
# [99570 rows x 5 columns]

# %%
dataset_regression["datetimeutc"]=pd.to_datetime(dataset_regression["datetimeutc"])
# Out:
# /home/shitiz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset_regression.set_index("datetimeutc",inplace=True)

# %%
dataset_regression
# Out:
#                        hum  tempm  pressurem  wspdm
# datetimeutc
# 1996-11-01 11:00:00   27.0   30.0     1010.0    7.4
# 1996-11-01 12:00:00   32.0   28.0    -9999.0    7.4
# 1996-11-01 13:00:00   44.0   24.0    -9999.0    7.4
# 1996-11-01 14:00:00   41.0   24.0     1010.0    7.4
# 1996-11-01 16:00:00   47.0   23.0     1011.0    0.0
# ...                    ...    ...        ...    ...
# 2016-12-31 12:00:00   77.0   18.0     1015.0    7.4
# 2016-12-31 13:00:00  100.0   16.0     1014.0    3.7
# 2016-12-31 15:00:00   58.0   27.0     1016.0   59.3
# 2016-12-31 18:00:00  100.0   12.0     1016.0    0.0
# 2016-12-31 21:00:00   99.0   12.0     1016.0    0.0
#
# [99570 rows x 4 columns]

# %%
dataset_regression=dataset_regression.resample("D").mean()
dataset_regression
# Out:
#                    hum      tempm    pressurem      wspdm
# datetimeutc
# 1996-11-01   52.916667  22.333333 -2659.666667   6.166667
# 1996-11-02   48.625000  22.916667  1009.833333   7.950000
# 1996-11-03   55.958333  21.791667  1010.500000   5.020833
# 1996-11-04   48.055556  22.722222  1011.333333   2.266667
# 1996-11-05   29.400000  27.800000  1011.800000  10.020000
# ...                ...        ...          ...        ...
# 2016-12-27   67.550000  16.850000  1017.200000   8.335000
# 2016-12-28   68.043478  17.217391  1015.565217   3.547826
# 2016-12-29   87.857143  15.238095  1016.904762   6.000000
# 2016-12-30   89.666667  14.095238  1017.904762   6.266667
# 2016-12-31   85.550000  15.650000  1016.100000   7.325000
#
# [7366 rows x 4 columns]

# %%
def extract_year(value):
  value=value.strftime('%Y-%m-%d')
  return (value[0:4])

# %%
def extract_month(value):
    value=value.strftime('%Y-%m-%d')
    return (value[4:6])

# %%
def extract_date(value):
    value=value.strftime('%Y-%m-%d')
    return (value[6:8])

# %%
dataset_regression.reset_index(inplace=True)

# %%
# dataset_regression["year"]=dataset_regression["datetimeutc"].apply(lambda x : extract_year(x))
# dataset_regression["month"]=dataset_regression["datetimeutc"].apply(lambda x : extract_month(x))
# dataset_regression["date"]=dataset_regression["datetimeutc"].apply(lambda x : extract_month(x))
dataset_regression['day'] = dataset_regression['datetimeutc'].dt.day
dataset_regression['month'] = dataset_regression['datetimeutc'].dt.month
dataset_regression['year'] = dataset_regression['datetimeutc'].dt.year

# %%
dataset_regression
# Out:
#      datetimeutc        hum      tempm    pressurem      wspdm  day  month  \
# 0     1996-11-01  52.916667  22.333333 -2659.666667   6.166667    1     11
# 1     1996-11-02  48.625000  22.916667  1009.833333   7.950000    2     11
# 2     1996-11-03  55.958333  21.791667  1010.500000   5.020833    3     11
# 3     1996-11-04  48.055556  22.722222  1011.333333   2.266667    4     11
# 4     1996-11-05  29.400000  27.800000  1011.800000  10.020000    5     11
# ...          ...        ...        ...          ...        ...  ...    ...
# 7361  2016-12-27  67.550000  16.850000  1017.200000   8.335000   27     12
# 7362  2016-12-28  68.043478  17.217391  1015.565217   3.547826   28     12
# 7363  2016-12-29  87.857143  15.238095  1016.904762   6.000000   29     12
# 7364  2016-12-30  89.666667  14.095238  1017.904762   6.266667   30     12
# 7365  2016-12-31  85.550000  15.650000  1016.100000   7.325000   31     12
#
#       year
# 0     1996
# 1     1996
# 2     1996
# 3     1996
# 4     1996
# ...    ...
# 7361  2016
# 7362  2016
# 7363  2016
# 7364  2016
# 7365  2016
#
# [7366 rows x 8 columns]

# %%
dataset_regression.isnull().sum()
# Out:
# datetimeutc      0
# hum            141
# tempm          141
# pressurem      141
# wspdm          141
# day              0
# month            0
# year             0
# dtype: int64

# %%
# dataset.groupby("year").tempm.mean()

# %%
dataset_regression.fillna(dataset_regression.mean(),inplace=True)
# Out:
# /home/shitiz/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   """Entry point for launching an IPython kernel.

# %%
dataset_regression.isnull().sum()
# Out:
# datetimeutc    0
# hum            0
# tempm          0
# pressurem      0
# wspdm          0
# day            0
# month          0
# year           0
# dtype: int64

# %%
dataset_regression=dataset_regression.drop(["datetimeutc"],axis=1)
dataset_regression
# Out:
#             hum      tempm    pressurem      wspdm  day  month  year
# 0     52.916667  22.333333 -2659.666667   6.166667    1     11  1996
# 1     48.625000  22.916667  1009.833333   7.950000    2     11  1996
# 2     55.958333  21.791667  1010.500000   5.020833    3     11  1996
# 3     48.055556  22.722222  1011.333333   2.266667    4     11  1996
# 4     29.400000  27.800000  1011.800000  10.020000    5     11  1996
# ...         ...        ...          ...        ...  ...    ...   ...
# 7361  67.550000  16.850000  1017.200000   8.335000   27     12  2016
# 7362  68.043478  17.217391  1015.565217   3.547826   28     12  2016
# 7363  87.857143  15.238095  1016.904762   6.000000   29     12  2016
# 7364  89.666667  14.095238  1017.904762   6.266667   30     12  2016
# 7365  85.550000  15.650000  1016.100000   7.325000   31     12  2016
#
# [7366 rows x 7 columns]

# %%
X_part=dataset_regression.drop(["tempm"],axis=1)
Y_part=dataset_regression["tempm"]
X_part=np.array(X_part)
Y_part=np.array(Y_part).reshape(-1,1)
print(X_part.shape)
print(Y_part.shape)
# Out:
# (7366, 6)
# (7366, 1)

# %%
scaler2=MinMaxScaler(feature_range=[-1,1])
X_part_scaled=scaler2.fit_transform(X_part)
Y_part_scaled=scaler2.fit_transform(Y_part)

# %%
step=30
input=[]
output=[]
for i in range(len(X_part_scaled)-(step)):
    input.append(X_part_scaled[i:i+step])
    output.append(Y_part_scaled[i+step])
 
input=np.array(input)
output=np.array(output)

print(input.shape)
print(output.shape)
# Out:
# (7336, 30, 6)
# (7336, 1)

# %%
trainR_X=input[:7000,::]
testR_X=input[7000:,::]
print("train_X Shape:",trainR_X.shape, ",test_X Shape:", testR_X.shape)

trainR_Y=output[:7000]
testR_Y=output[7000:]
print("test_Y Shape:",trainR_Y.shape, ",test_Y Shape:", testR_Y.shape)
# Out:
# train_X Shape: (7000, 30, 6) ,test_X Shape: (336, 30, 6)
# test_Y Shape: (7000, 1) ,test_Y Shape: (336, 1)

# %%
model2=models.Sequential()
model2.add(layers.Conv1D(filters=128, kernel_size=2, activation="relu", input_shape=(30,6)))
model2.add(layers.Conv1D(filters=128, kernel_size=2, activation="relu"))
model2.add(layers.MaxPool1D(pool_size=2))
model2.add(layers.Conv1D(filters=128, kernel_size=2, activation="relu"))
model2.add(layers.Flatten())
model2.add(layers.RepeatVector(30)) #same as input (30,1)=30
model2.add(layers.LSTM(units=100, return_sequences=True, activation="relu"))
model2.add(layers.Dropout(0.2))
model2.add(layers.LSTM(units=100, return_sequences=True, activation="relu"))
model2.add(layers.Dropout(0.2))
model2.add(layers.Bidirectional(layers.LSTM(units=128, activation="relu")))
model2.add(layers.Dense(100, activation="relu"))
model2.add(layers.Dense(1))

# %%
model2.compile(optimizer=optimizers.Adam(lr=0.001), loss="mae", metrics=["mse"])
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 29, 128)           1664
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 28, 128)           32896
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 14, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 13, 128)           32896
# _________________________________________________________________
# flatten (Flatten)            (None, 1664)              0
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 30, 1664)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 30, 100)           706000
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 100)           80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 100)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               234496
# _________________________________________________________________
# dense (Dense)                (None, 100)               25700
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 1,114,153
# Trainable params: 1,114,153
# Non-trainable params: 0
# _________________________________________________________________

# %%
EarlyStp=callbacks.EarlyStopping(monitor="loss", mode="min", patience=5)
Savemod=callbacks.ModelCheckpoint(filepath="Models/model2_R.h5", monitor="loss", save_best_only=True)

# %%
history=model2.fit(trainR_X, trainR_Y, epochs=200,callbacks=[Savemod, EarlyStp])
# Out:
# Epoch 1/200
# 219/219 [==============================] - 130s 508ms/step - loss: 0.2598 - mse: 0.3810
# Epoch 2/200
# 219/219 [==============================] - 81s 369ms/step - loss: 0.1164 - mse: 0.0216
# Epoch 3/200
# 219/219 [==============================] - 79s 361ms/step - loss: 0.1079 - mse: 0.0191
# Epoch 4/200
# 219/219 [==============================] - 78s 358ms/step - loss: 0.1066 - mse: 0.0184
# Epoch 5/200
# 219/219 [==============================] - 80s 366ms/step - loss: 0.1037 - mse: 0.0176
# Epoch 6/200
# 219/219 [==============================] - 79s 358ms/step - loss: 0.1014 - mse: 0.0171
# Epoch 7/200
# 219/219 [==============================] - 79s 358ms/step - loss: 0.0979 - mse: 0.0162
# Epoch 8/200
# 219/219 [==============================] - 79s 359ms/step - loss: 0.0942 - mse: 0.0146
# Epoch 9/200
# 219/219 [==============================] - 79s 358ms/step - loss: 0.0920 - mse: 0.0142
# Epoch 10/200
# 219/219 [==============================] - 78s 357ms/step - loss: 0.0910 - mse: 0.0140
# Epoch 11/200
# 219/219 [==============================] - 79s 360ms/step - loss: 0.0913 - mse: 0.0138
# Epoch 12/200
# 219/219 [==============================] - 79s 359ms/step - loss: 0.0880 - mse: 0.0135
# Epoch 13/200
# 219/219 [==============================] - 79s 359ms/step - loss: 0.0883 - mse: 0.0135
# Epoch 14/200
# 219/219 [==============================] - 79s 359ms/step - loss: 0.0868 - mse: 0.0131
# Epoch 15/200
# 219/219 [==============================] - 79s 361ms/step - loss: 0.0836 - mse: 0.0122
# Epoch 16/200
# 219/219 [==============================] - 78s 358ms/step - loss: 0.0830 - mse: 0.0120
# Epoch 17/200
# 219/219 [==============================] - 79s 361ms/step - loss: 0.0806 - mse: 0.0113
# Epoch 18/200
# 219/219 [==============================] - 79s 360ms/step - loss: 0.0791 - mse: 0.0116
# Epoch 19/200
# 219/219 [==============================] - 80s 365ms/step - loss: 0.0778 - mse: 0.0108
# Epoch 20/200
# 219/219 [==============================] - 80s 367ms/step - loss: 0.0746 - mse: 0.0103
# Epoch 21/200
# 219/219 [==============================] - 83s 377ms/step - loss: 0.0765 - mse: 0.0105
# Epoch 22/200
# 219/219 [==============================] - 78s 358ms/step - loss: 0.0740 - mse: 0.0096
# Epoch 23/200
# 219/219 [==============================] - 79s 361ms/step - loss: 0.0726 - mse: 0.0097
# Epoch 24/200
# 219/219 [==============================] - 79s 362ms/step - loss: 0.0713 - mse: 0.0095
# Epoch 25/200
# 219/219 [==============================] - 79s 361ms/step - loss: 0.0702 - mse: 0.0091
# Epoch 26/200
# 219/219 [==============================] - 80s 364ms/step - loss: 0.0681 - mse: 0.0085
# Epoch 27/200
# 219/219 [==============================] - 79s 360ms/step - loss: 0.0680 - mse: 0.0087
# Epoch 28/200
# 219/219 [==============================] - 81s 370ms/step - loss: 0.0682 - mse: 0.0084
# Epoch 29/200
# 219/219 [==============================] - 80s 363ms/step - loss: 0.0664 - mse: 0.0082
# Epoch 30/200
# 219/219 [==============================] - 79s 362ms/step - loss: 0.0622 - mse: 0.0075
# Epoch 31/200
# 219/219 [==============================] - 80s 363ms/step - loss: 0.0637 - mse: 0.0080
# Epoch 32/200
# 219/219 [==============================] - 79s 362ms/step - loss: 0.0604 - mse: 0.0069
# Epoch 33/200
# 219/219 [==============================] - 80s 363ms/step - loss: 0.0584 - mse: 0.0067
# Epoch 34/200
# 219/219 [==============================] - 80s 364ms/step - loss: 0.0552 - mse: 0.0059
# Epoch 35/200
# 219/219 [==============================] - 81s 370ms/step - loss: 0.0561 - mse: 0.0064
# Epoch 36/200
# 219/219 [==============================] - 81s 369ms/step - loss: 0.0550 - mse: 0.0058
# Epoch 37/200
# 219/219 [==============================] - 80s 364ms/step - loss: 0.0542 - mse: 0.0058
# Epoch 38/200
# 219/219 [==============================] - 81s 369ms/step - loss: 0.0537 - mse: 0.0056
# Epoch 39/200
# 219/219 [==============================] - 80s 366ms/step - loss: 0.0515 - mse: 0.0051
# Epoch 40/200
# 219/219 [==============================] - 80s 366ms/step - loss: 0.0639 - mse: 0.0263
# Epoch 41/200
# 219/219 [==============================] - 80s 367ms/step - loss: 0.0577 - mse: 0.0065
# Epoch 42/200
# 219/219 [==============================] - 85s 388ms/step - loss: 0.0506 - mse: 0.0051
# Epoch 43/200
# 219/219 [==============================] - 83s 377ms/step - loss: 0.0491 - mse: 0.0046
# Epoch 44/200
# 219/219 [==============================] - 81s 372ms/step - loss: 0.0468 - mse: 0.0045
# Epoch 45/200
# 219/219 [==============================] - 79s 360ms/step - loss: 0.0468 - mse: 0.0043
# Epoch 46/200
# 219/219 [==============================] - 80s 363ms/step - loss: 0.0470 - mse: 0.0044
# Epoch 47/200
# 219/219 [==============================] - 80s 365ms/step - loss: 0.0446 - mse: 0.0043
# Epoch 48/200
# 219/219 [==============================] - 80s 365ms/step - loss: 0.0427 - mse: 0.0037
# Epoch 49/200
# 219/219 [==============================] - 80s 364ms/step - loss: 0.0414 - mse: 0.0035
# Epoch 50/200
# 219/219 [==============================] - 80s 364ms/step - loss: 0.0411 - mse: 0.0036
# Epoch 51/200
# 219/219 [==============================] - 80s 366ms/step - loss: 0.0403 - mse: 0.0033
# Epoch 52/200
# 219/219 [==============================] - 80s 364ms/step - loss: 0.0372 - mse: 0.0029
# Epoch 53/200
# 219/219 [==============================] - 78s 355ms/step - loss: 0.0385 - mse: 0.0031
# Epoch 54/200
# 219/219 [==============================] - 78s 355ms/step - loss: 0.0371 - mse: 0.0029
# Epoch 55/200
# 219/219 [==============================] - 78s 355ms/step - loss: 0.0370 - mse: 0.0028
# Epoch 56/200
# 219/219 [==============================] - 78s 354ms/step - loss: 0.0365 - mse: 0.0027
# Epoch 57/200
# 219/219 [==============================] - 78s 355ms/step - loss: 0.0365 - mse: 0.0032
# Epoch 58/200
# 219/219 [==============================] - 77s 353ms/step - loss: 0.0359 - mse: 0.0027
# Epoch 59/200
# 110/219 [==============>...............] - ETA: 38s - loss: 0.0333 - mse: 0.0022

# %%
hist=history.history
train_loss=hist["loss"]
epoch=range(1,len(train_loss)+1)

# %%
plt.plot(epoch,train_loss)

# %%
model=models.load_model("Models/model2_R.h5")

# %%
temp_rs=model.predict(testR_X)

# %%
temp_rs=scaler2.inverse_transform(temp_rs)
temp_rs
# Out:
# array([[15.938739 ],
#        [15.423775 ],
#        [15.657267 ],
#        [17.859152 ],
#        [18.7911   ],
#        [17.83936  ],
#        [17.46794  ],
#        [18.756084 ],
#        [14.776162 ],
#        [14.165221 ],
#        [14.834968 ],
#        [15.167963 ],
#        [15.674199 ],
#        [17.094086 ],
#        [18.320646 ],
#        [15.93987  ],
#        [15.536605 ],
#        [16.823141 ],
#        [19.703403 ],
#        [20.5249   ],
#        [19.936026 ],
#        [22.429705 ],
#        [22.308502 ],
#        [18.773062 ],
#        [17.813108 ],
#        [20.82041  ],
#        [20.801321 ],
#        [18.885027 ],
#        [18.286484 ],
#        [18.567905 ],
#        [19.354815 ],
#        [19.285656 ],
#        [21.236975 ],
#        [18.98763  ],
#        [18.928171 ],
#        [18.941277 ],
#        [22.90221  ],
#        [19.067152 ],
#        [17.214298 ],
#        [17.29136  ],
#        [20.352255 ],
#        [20.795202 ],
#        [22.130945 ],
#        [22.318336 ],
#        [25.333998 ],
#        [26.87023  ],
#        [26.427265 ],
#        [27.01629  ],
#        [26.611645 ],
#        [25.391426 ],
#        [22.683268 ],
#        [23.200361 ],
#        [26.724571 ],
#        [28.017828 ],
#        [25.737513 ],
#        [25.311684 ],
#        [21.689665 ],
#        [23.125694 ],
#        [26.304884 ],
#        [25.082499 ],
#        [24.3058   ],
#        [25.557428 ],
#        [26.63322  ],
#        [28.03382  ],
#        [28.409533 ],
#        [27.965652 ],
#        [27.64285  ],
#        [28.119314 ],
#        [27.336535 ],
#        [29.157854 ],
#        [28.073256 ],
#        [27.29404  ],
#        [27.184483 ],
#        [25.619335 ],
#        [26.188147 ],
#        [28.64698  ],
#        [28.570608 ],
#        [29.250168 ],
#        [29.138042 ],
#        [29.695253 ],
#        [28.837374 ],
#        [30.689548 ],
#        [31.128756 ],
#        [31.353832 ],
#        [30.68566  ],
#        [30.177395 ],
#        [30.18604  ],
#        [30.70612  ],
#        [31.273365 ],
#        [31.651558 ],
#        [31.598791 ],
#        [31.950031 ],
#        [32.019135 ],
#        [31.655865 ],
#        [31.959852 ],
#        [31.425812 ],
#        [31.011267 ],
#        [31.281258 ],
#        [31.404556 ],
#        [31.30197  ],
#        [30.070196 ],
#        [28.387476 ],
#        [26.315641 ],
#        [25.982075 ],
#        [26.277502 ],
#        [29.499836 ],
#        [31.362835 ],
#        [31.758059 ],
#        [35.642593 ],
#        [35.220848 ],
#        [34.503036 ],
#        [33.272434 ],
#        [33.64046  ],
#        [35.027493 ],
#        [31.743444 ],
#        [29.471828 ],
#        [29.0706   ],
#        [28.91444  ],
#        [31.02339  ],
#        [29.869398 ],
#        [30.716278 ],
#        [31.119102 ],
#        [32.304104 ],
#        [34.45596  ],
#        [34.016617 ],
#        [34.086845 ],
#        [33.92738  ],
#        [31.511997 ],
#        [32.04339  ],
#        [27.854698 ],
#        [25.921305 ],
#        [25.305164 ],
#        [27.068365 ],
#        [29.046738 ],
#        [30.89652  ],
#        [31.763777 ],
#        [31.500635 ],
#        [31.34439  ],
#        [30.939152 ],
#        [30.617565 ],
#        [31.989378 ],
#        [32.30593  ],
#        [31.991795 ],
#        [31.332869 ],
#        [31.043152 ],
#        [30.940775 ],
#        [30.673267 ],
#        [30.017675 ],
#        [30.518412 ],
#        [31.31261  ],
#        [30.101326 ],
#        [30.680891 ],
#        [31.249985 ],
#        [28.042938 ],
#        [27.60295  ],
#        [28.945154 ],
#        [30.84299  ],
#        [30.419624 ],
#        [32.386906 ],
#        [31.556166 ],
#        [27.996637 ],
#        [28.920805 ],
#        [30.504753 ],
#        [28.93139  ],
#        [28.893368 ],
#        [28.638962 ],
#        [29.314959 ],
#        [29.630716 ],
#        [29.564392 ],
#        [29.243814 ],
#        [28.510555 ],
#        [28.288107 ],
#        [29.621477 ],
#        [30.761621 ],
#        [30.721027 ],
#        [30.307566 ],
#        [30.18355  ],
#        [31.198957 ],
#        [29.590696 ],
#        [29.038975 ],
#        [29.384295 ],
#        [28.631655 ],
#        [29.924278 ],
#        [29.22188  ],
#        [28.31382  ],
#        [29.966463 ],
#        [29.63354  ],
#        [27.427292 ],
#        [28.0467   ],
#        [28.050055 ],
#        [28.246725 ],
#        [29.578196 ],
#        [29.682337 ],
#        [30.151514 ],
#        [30.245125 ],
#        [30.230385 ],
#        [30.298145 ],
#        [28.4348   ],
#        [29.070135 ],
#        [30.156923 ],
#        [28.91798  ],
#        [28.307194 ],
#        [28.43974  ],
#        [28.664257 ],
#        [29.070406 ],
#        [28.987955 ],
#        [28.421259 ],
#        [27.790972 ],
#        [29.93806  ],
#        [30.505247 ],
#        [29.700743 ],
#        [30.383938 ],
#        [27.570044 ],
#        [28.329184 ],
#        [27.274023 ],
#        [26.869877 ],
#        [28.486826 ],
#        [28.14156  ],
#        [28.41439  ],
#        [29.179964 ],
#        [29.756004 ],
#        [29.669441 ],
#        [29.78111  ],
#        [30.846828 ],
#        [30.249266 ],
#        [30.049932 ],
#        [30.990253 ],
#        [30.908175 ],
#        [30.187891 ],
#        [30.517677 ],
#        [31.112354 ],
#        [30.667477 ],
#        [30.611448 ],
#        [29.67827  ],
#        [29.239088 ],
#        [29.834888 ],
#        [29.45027  ],
#        [28.882122 ],
#        [28.462458 ],
#        [29.089117 ],
#        [29.254995 ],
#        [29.167612 ],
#        [29.193554 ],
#        [28.669928 ],
#        [28.784054 ],
#        [29.09625  ],
#        [28.768452 ],
#        [28.153948 ],
#        [28.219463 ],
#        [28.596008 ],
#        [29.018934 ],
#        [29.021856 ],
#        [28.637403 ],
#        [28.013607 ],
#        [25.18244  ],
#        [26.146944 ],
#        [27.100027 ],
#        [26.943203 ],
#        [27.496931 ],
#        [28.97717  ],
#        [28.185148 ],
#        [27.511667 ],
#        [27.637598 ],
#        [28.353807 ],
#        [27.33264  ],
#        [27.925076 ],
#        [23.229874 ],
#        [20.505116 ],
#        [26.977486 ],
#        [28.480282 ],
#        [28.121494 ],
#        [28.104485 ],
#        [27.826653 ],
#        [26.835875 ],
#        [24.997791 ],
#        [26.183348 ],
#        [26.258389 ],
#        [24.14897  ],
#        [23.443424 ],
#        [22.932642 ],
#        [23.501537 ],
#        [22.487862 ],
#        [21.352207 ],
#        [18.570007 ],
#        [22.39398  ],
#        [22.235157 ],
#        [24.369158 ],
#        [21.850534 ],
#        [21.46173  ],
#        [20.314854 ],
#        [21.073938 ],
#        [19.809711 ],
#        [18.122488 ],
#        [16.993626 ],
#        [18.272318 ],
#        [17.384935 ],
#        [17.80942  ],
#        [17.301394 ],
#        [17.995874 ],
#        [19.188591 ],
#        [20.286749 ],
#        [19.098812 ],
#        [19.772573 ],
#        [19.840403 ],
#        [20.195372 ],
#        [19.221766 ],
#        [19.470446 ],
#        [19.539774 ],
#        [20.143803 ],
#        [19.35623  ],
#        [18.683773 ],
#        [19.556934 ],
#        [20.164066 ],
#        [19.230139 ],
#        [17.872866 ],
#        [16.59085  ],
#        [15.671915 ],
#        [14.818551 ],
#        [14.608818 ],
#        [14.604799 ],
#        [14.888062 ],
#        [14.467241 ],
#        [12.945266 ],
#        [12.553348 ],
#        [11.905302 ],
#        [12.041206 ],
#        [12.538986 ],
#        [12.4033165],
#        [12.264418 ],
#        [13.139493 ],
#        [14.799778 ],
#        [14.860374 ],
#        [19.643133 ],
#        [19.41293  ],
#        [17.76797  ],
#        [16.939173 ]], dtype=float32)

# %%
testR_Y_inv=scaler2.inverse_transform(testR_Y)

# %%
scale_factor=0.5
plt.figure(figsize=(20,9))
plt.plot(testR_Y_inv ,linewidth=2)
plt.plot(temp_rs,linewidth=3)
ymin,ymax=plt.ylim()
plt.ylim(ymin * scale_factor, ymax)
plt.xlabel("Time", fontsize=20)
plt.ylabel("Temperature (C)", fontsize=20)
plt.legend(('Test','Predicted'))
plt.savefig('Plots/Regression_Model.png')
plt.show()

# %%
df = pd.DataFrame({'Real Values':testR_Y_inv.reshape(-1), 'Predicted Values':temp_rs.reshape(-1)})
df
# Out:
#      Real Values  Predicted Values
# 0      17.375000         15.938739
# 1      15.846154         15.423775
# 2      15.266667         15.657267
# 3      14.666667         17.859152
# 4      17.250000         18.791100
# ..           ...               ...
# 331    16.850000         14.860374
# 332    17.217391         19.643133
# 333    15.238095         19.412930
# 334    14.095238         17.767969
# 335    15.650000         16.939173
#
# [336 rows x 2 columns]

# %%
mse=mean_squared_error(testR_Y_inv, temp_rs,squared=False)
mae=mean_absolute_error(testR_Y_inv, temp_rs)
r2=r2_score(testR_Y_inv, temp_rs)
print("Mean Squared Error:", str(mse), "and Mean Absolute Error:", str(mae))
print(f'{r2}')
# Out:
# Mean Squared Error: 3.509434082058648 and Mean Absolute Error: 2.8702791393913314
# 0.6623786245938126

# %%
test=pd.read_csv("archive/DailyDelhiClimateTest.csv")
test
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
test.isnull().sum()
# Out:
# date            0
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
test["date"]=pd.to_datetime(test["date"])
test.set_index("date",inplace=True)
test
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2017-01-01  15.913043  85.869565    2.743478     59.000000
# 2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ...               ...        ...         ...           ...
# 2017-04-20  34.500000  27.500000    5.562500    998.625000
# 2017-04-21  34.250000  39.375000    6.962500    999.875000
# 2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 4 columns]

# %%
def extract_year(value):
  value=value.strftime('%Y-%m-%d')
  return (value[0:4])

# %%
def extract_month(value):
    value=value.strftime('%Y-%m-%d')
    return (value[4:6])

# %%
def extract_date(value):
    value=value.strftime('%Y-%m-%d')
    return (value[6:8])

# %%
test.reset_index(inplace=True)

# %%
test['day'] = test['date'].dt.day
test['month'] = test['date'].dt.month
test['year'] = test['date'].dt.year

# %%
test
temp=test.drop(["wind_speed"],axis=1)
temp=temp.append(test["wind_speed"])
# temp

# %%
test=test.drop(["date"],axis=1)
test
# Out:
#       meantemp   humidity  wind_speed  meanpressure  day  month  year
# 0    15.913043  85.869565    2.743478     59.000000    1      1  2017
# 1    18.500000  77.222222    2.894444   1018.277778    2      1  2017
# 2    17.111111  81.888889    4.016667   1018.333333    3      1  2017
# 3    18.700000  70.050000    4.545000   1015.700000    4      1  2017
# 4    18.388889  74.944444    3.300000   1014.333333    5      1  2017
# ..         ...        ...         ...           ...  ...    ...   ...
# 109  34.500000  27.500000    5.562500    998.625000   20      4  2017
# 110  34.250000  39.375000    6.962500    999.875000   21      4  2017
# 111  32.900000  40.900000    8.890000   1001.600000   22      4  2017
# 112  32.875000  27.500000    9.962500   1002.125000   23      4  2017
# 113  32.000000  27.142857   12.157143   1004.142857   24      4  2017
#
# [114 rows x 7 columns]

# %%
X_part=test.drop(["meantemp"],axis=1)
X_part=X_part[['humidity','meanpressure','wind_speed','day','month','year']]
X_part
# Out:
#       humidity  meanpressure  wind_speed  day  month  year
# 0    85.869565     59.000000    2.743478    1      1  2017
# 1    77.222222   1018.277778    2.894444    2      1  2017
# 2    81.888889   1018.333333    4.016667    3      1  2017
# 3    70.050000   1015.700000    4.545000    4      1  2017
# 4    74.944444   1014.333333    3.300000    5      1  2017
# ..         ...           ...         ...  ...    ...   ...
# 109  27.500000    998.625000    5.562500   20      4  2017
# 110  39.375000    999.875000    6.962500   21      4  2017
# 111  40.900000   1001.600000    8.890000   22      4  2017
# 112  27.500000   1002.125000    9.962500   23      4  2017
# 113  27.142857   1004.142857   12.157143   24      4  2017
#
# [114 rows x 6 columns]

# %%
Y_part=test["meantemp"]
X_part=np.array(X_part)
Y_part=np.array(Y_part).reshape(-1,1)
print(X_part.shape)
print(Y_part.shape)
# Out:
# (114, 6)
# (114, 1)

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
scaler2=MinMaxScaler(feature_range=[-1,1])
X_part_scaled=scaler2.fit_transform(X_part)
Y_part_scaled=scaler2.fit_transform(Y_part)

# %%
step=30
input=[]
output=[]
for i in range(len(X_part_scaled)-(step)):
    input.append(X_part_scaled[i:i+step])
    output.append(Y_part_scaled[i+step])
 
input=np.array(input)
output=np.array(output)

print(input.shape)
print(output.shape)
# Out:
# (84, 30, 6)
# (84, 1)

# %%
temp_rs=model.predict(input)

# %%
temp_rs=scaler2.inverse_transform(temp_rs)
temp_rs
# Out:
# array([[15.913237],
#        [15.482143],
#        [15.405111],
#        [15.411045],
#        [15.562571],
#        [15.540784],
#        [15.947277],
#        [16.235495],
#        [16.738829],
#        [18.052153],
#        [18.756605],
#        [16.842924],
#        [16.403183],
#        [18.892109],
#        [19.5801  ],
#        [19.976444],
#        [19.580513],
#        [20.013762],
#        [19.694921],
#        [20.649836],
#        [19.07864 ],
#        [20.749575],
#        [20.666494],
#        [20.224852],
#        [26.589725],
#        [27.49571 ],
#        [27.988777],
#        [27.652925],
#        [21.34771 ],
#        [18.957174],
#        [18.081709],
#        [17.846111],
#        [18.089664],
#        [22.9523  ],
#        [25.13258 ],
#        [18.483604],
#        [24.801638],
#        [18.3123  ],
#        [15.684777],
#        [16.035885],
#        [17.065973],
#        [17.567556],
#        [18.471571],
#        [19.781555],
#        [25.660645],
#        [27.81328 ],
#        [27.421497],
#        [26.870008],
#        [27.16551 ],
#        [28.31205 ],
#        [28.76813 ],
#        [28.678263],
#        [28.379179],
#        [28.25732 ],
#        [27.69104 ],
#        [26.899216],
#        [26.944935],
#        [27.648342],
#        [27.940218],
#        [28.369442],
#        [27.688019],
#        [23.126547],
#        [19.26224 ],
#        [18.488478],
#        [18.849388],
#        [17.777042],
#        [18.093336],
#        [16.415682],
#        [16.78256 ],
#        [18.124039],
#        [17.79209 ],
#        [17.840504],
#        [18.75765 ],
#        [23.505102],
#        [21.679564],
#        [20.019863],
#        [19.323486],
#        [20.7958  ],
#        [21.960926],
#        [28.171572],
#        [28.873512],
#        [28.755474],
#        [28.377745],
#        [28.3069  ]], dtype=float32)

# %%
Y_test_inv=scaler2.inverse_transform(Y_part)

# %%
from sklearn import metrics
mse=mean_squared_error(Y_test_inv,temp_rs,squared=False)
mae=mean_absolute_error(Y_test_inv,temp_rs)
print(f'{mse} {mae} {metrics.r2_score(Y_test_inv,temp_rs)}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-83ca2f7f2233> in <module>
#       1 from sklearn import metrics
# ----> 2 mse=mean_squared_error(Y_test_inv,temp_rs,squared=False)
#       3 mae=mean_absolute_error(Y_test_inv,temp_rs)
#       4 print(f'{mse} {mae} {metrics.r2_score(Y_test_inv,temp_rs)}')
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     254     """
#     255     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 256         y_true, y_pred, multioutput)
#     257     check_consistent_length(y_true, y_pred, sample_weight)
#     258     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     254     if len(uniques) > 1:
#     255         raise ValueError("Found input variables with inconsistent numbers of"
# --> 256                          " samples: %r" % [int(l) for l in lengths])
#     257
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [114, 84]
