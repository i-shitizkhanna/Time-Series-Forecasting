# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
from numpy.random import seed
seed(1)
tf.random.set_seed(1)

# %%
dataset=pd.read_csv("Data/testset.csv")
dataset
# Out:
#          datetime_utc          _conds  _dewptm  _fog  _hail  _heatindexm  \
# 0      19961101-11:00           Smoke      9.0     0      0          NaN
# 1      19961101-12:00           Smoke     10.0     0      0          NaN
# 2      19961101-13:00           Smoke     11.0     0      0          NaN
# 3      19961101-14:00           Smoke     10.0     0      0          NaN
# 4      19961101-16:00           Smoke     11.0     0      0          NaN
# ...               ...             ...      ...   ...    ...          ...
# 99565  20161231-12:00   Partly Cloudy     15.0     0      0          NaN
# 99566  20161231-13:00   Partly Cloudy     16.0     0      0          NaN
# 99567  20161231-15:00             NaN     13.0     0      0          NaN
# 99568  20161231-18:00  Patches of Fog     12.0     1      0          NaN
# 99569  20161231-21:00  Patches of Fog     12.0     1      0          NaN
#
#         _hum  _precipm  _pressurem  _rain  _snow  _tempm  _thunder  _tornado  \
# 0       27.0       NaN      1010.0      0      0    30.0         0         0
# 1       32.0       NaN     -9999.0      0      0    28.0         0         0
# 2       44.0       NaN     -9999.0      0      0    24.0         0         0
# 3       41.0       NaN      1010.0      0      0    24.0         0         0
# 4       47.0       NaN      1011.0      0      0    23.0         0         0
# ...      ...       ...         ...    ...    ...     ...       ...       ...
# 99565   77.0       NaN      1015.0      0      0    18.0         0         0
# 99566  100.0       NaN      1014.0      0      0    16.0         0         0
# 99567    NaN       NaN      1016.0      0      0     NaN         0         0
# 99568  100.0       NaN      1016.0      0      0    12.0         0         0
# 99569   99.0       NaN      1016.0      0      0    12.0         0         0
#
#        _vism  _wdird _wdire  _wgustm  _windchillm  _wspdm
# 0       5.00   280.0   West      NaN          NaN     7.4
# 1        NaN     0.0  North      NaN          NaN     NaN
# 2        NaN     0.0  North      NaN          NaN     NaN
# 3       2.00     0.0  North      NaN          NaN     NaN
# 4       1.20     0.0  North      NaN          NaN     0.0
# ...      ...     ...    ...      ...          ...     ...
# 99565   0.50   110.0    ESE      NaN          NaN     7.4
# 99566   0.80    90.0   East      NaN          NaN     3.7
# 99567   0.05    10.0  North      NaN          NaN    59.3
# 99568   0.50     NaN    NaN      NaN          NaN     0.0
# 99569   0.50     NaN    NaN      NaN          NaN     0.0
#
# [99570 rows x 20 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99570 entries, 0 to 99569
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime_utc  99570 non-null  object
#  1   _conds        99500 non-null  object
#  2   _dewptm       98950 non-null  float64
#  3   _fog          99570 non-null  int64
#  4   _hail         99570 non-null  int64
#  5   _heatindexm   29113 non-null  float64
#  6   _hum          98814 non-null  float64
#  7   _precipm      0 non-null      float64
#  8   _pressurem    99338 non-null  float64
#  9   _rain         99570 non-null  int64
#  10  _snow         99570 non-null  int64
#  11  _tempm        98898 non-null  float64
#  12  _thunder      99570 non-null  int64
#  13  _tornado      99570 non-null  int64
#  14  _vism         95142 non-null  float64
#  15  _wdird        85078 non-null  float64
#  16  _wdire        85078 non-null  object
#  17  _wgustm       1063 non-null   float64
#  18  _windchillm   573 non-null    float64
#  19  _wspdm        97212 non-null  float64
# dtypes: float64(11), int64(6), object(3)
# memory usage: 15.2+ MB

# %%
dataset.describe()
# Out:
#             _dewptm          _fog         _hail   _heatindexm          _hum  \
# count  98950.000000  99570.000000  99570.000000  29113.000000  98814.000000
# mean      15.788388      0.068746      0.000131     35.659046     57.848260
# std        7.085844      0.253022      0.011426      5.013863     23.765629
# min      -24.000000      0.000000      0.000000     26.800000      4.000000
# 25%       10.000000      0.000000      0.000000     31.700000     39.000000
# 50%       15.000000      0.000000      0.000000     35.100000     58.000000
# 75%       22.000000      0.000000      0.000000     39.200000     78.000000
# max       75.000000      1.000000      1.000000     73.600000    243.000000
#
#        _precipm    _pressurem         _rain         _snow        _tempm  \
# count       0.0  9.933800e+04  99570.000000  99570.000000  98898.000000
# mean        NaN  1.945683e+03      0.026323      0.000010     25.526553
# std         NaN  3.206461e+05      0.160095      0.003169      8.471719
# min         NaN -9.999000e+03      0.000000      0.000000      1.000000
# 25%         NaN  1.002000e+03      0.000000      0.000000     19.000000
# 50%         NaN  1.008000e+03      0.000000      0.000000     27.000000
# 75%         NaN  1.014000e+03      0.000000      0.000000     32.000000
# max         NaN  1.010614e+08      1.000000      1.000000     90.000000
#
#            _thunder      _tornado         _vism        _wdird      _wgustm  \
# count  99570.000000  99570.000000  95142.000000  85078.000000  1063.000000
# mean       0.009300      0.000020      2.411756    162.660053    37.704516
# std        0.095987      0.004482     20.899818    119.994031     6.841070
# min        0.000000      0.000000      0.000000      0.000000    25.900000
# 25%        0.000000      0.000000      1.500000     50.000000    33.300000
# 50%        0.000000      0.000000      2.000000    150.000000    37.000000
# 75%        0.000000      0.000000      3.000000    270.000000    40.700000
# max        1.000000      1.000000   6436.000000    960.000000    92.600000
#
#        _windchillm        _wspdm
# count   573.000000  97212.000000
# mean      5.708202      7.674429
# std       1.205967     11.982335
# min       2.100000      0.000000
# 25%       4.900000      0.000000
# 50%       6.100000      7.400000
# 75%       6.800000     11.100000
# max       7.300000   1514.900000

# %%
dataset.columns=dataset.columns.str.replace("_","")
dataset.columns=dataset.columns.str.replace(" ","")
dataset.columns
# Out:
# Index(['datetimeutc', 'conds', 'dewptm', 'fog', 'hail', 'heatindexm', 'hum',
#        'precipm', 'pressurem', 'rain', 'snow', 'tempm', 'thunder', 'tornado',
#        'vism', 'wdird', 'wdire', 'wgustm', 'windchillm', 'wspdm'],
#       dtype='object')

# %%
# dataset.drop("conds",inplace=True,axis=1)
# dataset.drop(,inplace=True,axis=1)
# dataset.drop(,inplace=True,axis=1)
# dataset.drop(inplace=True,axis=1)
# dataset.drop(,inplace=True,axis=1)
# dataset.drop(inplace=True,axis=1)
# dataset.drop(inplace=True,axis=1)
# dataset.drop(,inplace=True,axis=1)
dataset.drop(columns=["conds","dewptm","fog","hail","heatindexm","precipm","rain","snow","thunder","tornado","vism","wdird","wdire","wgustm","windchillm"],inplace=True,axis=1)
dataset
# Out:
#           datetimeutc    hum  pressurem  tempm  wspdm
# 0      19961101-11:00   27.0     1010.0   30.0    7.4
# 1      19961101-12:00   32.0    -9999.0   28.0    NaN
# 2      19961101-13:00   44.0    -9999.0   24.0    NaN
# 3      19961101-14:00   41.0     1010.0   24.0    NaN
# 4      19961101-16:00   47.0     1011.0   23.0    0.0
# ...               ...    ...        ...    ...    ...
# 99565  20161231-12:00   77.0     1015.0   18.0    7.4
# 99566  20161231-13:00  100.0     1014.0   16.0    3.7
# 99567  20161231-15:00    NaN     1016.0    NaN   59.3
# 99568  20161231-18:00  100.0     1016.0   12.0    0.0
# 99569  20161231-21:00   99.0     1016.0   12.0    0.0
#
# [99570 rows x 5 columns]

# %%
dataset.replace(0,np.nan)
dataset.isnull().sum()
# Out:
# datetimeutc       0
# hum             756
# pressurem       232
# tempm           672
# wspdm          2358
# dtype: int64

# %%
hum_median=dataset["hum"].median()
dataset["hum"].fillna(hum_median,inplace=True)
pressurem_median=dataset["pressurem"].median()
dataset["pressurem"].fillna(pressurem_median,inplace=True)
wspdm_median=dataset["wspdm"].median()
dataset["wspdm"].fillna(wspdm_median,inplace=True)
tempm_median=dataset["tempm"].median()
dataset["tempm"].fillna(tempm_median,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# datetimeutc    0
# hum            0
# pressurem      0
# tempm          0
# wspdm          0
# dtype: int64

# %%
timeseries_data=dataset.copy()

# %%
timeseries_data["datetimeutc"].dtype
# Out:
# dtype('O')

# %%
timeseries_data["datetimeutc"]=pd.to_datetime(timeseries_data["datetimeutc"])

# %%
timeseries_data.set_index("datetimeutc",inplace=True)

# %%
timeseries_data
# Out:
#                        hum  pressurem  tempm  wspdm
# datetimeutc
# 1996-11-01 11:00:00   27.0     1010.0   30.0    7.4
# 1996-11-01 12:00:00   32.0    -9999.0   28.0    7.4
# 1996-11-01 13:00:00   44.0    -9999.0   24.0    7.4
# 1996-11-01 14:00:00   41.0     1010.0   24.0    7.4
# 1996-11-01 16:00:00   47.0     1011.0   23.0    0.0
# ...                    ...        ...    ...    ...
# 2016-12-31 12:00:00   77.0     1015.0   18.0    7.4
# 2016-12-31 13:00:00  100.0     1014.0   16.0    3.7
# 2016-12-31 15:00:00   58.0     1016.0   27.0   59.3
# 2016-12-31 18:00:00  100.0     1016.0   12.0    0.0
# 2016-12-31 21:00:00   99.0     1016.0   12.0    0.0
#
# [99570 rows x 4 columns]

# %%
data_daily=timeseries_data.resample("D").mean()
data_daily
# Out:
#                    hum    pressurem      tempm      wspdm
# datetimeutc
# 1996-11-01   52.916667 -2659.666667  22.333333   6.166667
# 1996-11-02   48.625000  1009.833333  22.916667   7.950000
# 1996-11-03   55.958333  1010.500000  21.791667   5.020833
# 1996-11-04   48.055556  1011.333333  22.722222   2.266667
# 1996-11-05   29.400000  1011.800000  27.800000  10.020000
# ...                ...          ...        ...        ...
# 2016-12-27   67.550000  1017.200000  16.850000   8.335000
# 2016-12-28   68.043478  1015.565217  17.217391   3.547826
# 2016-12-29   87.857143  1016.904762  15.238095   6.000000
# 2016-12-30   89.666667  1017.904762  14.095238   6.266667
# 2016-12-31   85.550000  1016.100000  15.650000   7.325000
#
# [7366 rows x 4 columns]

# %%
data_daily.isnull().sum()
# Out:
# hum          141
# pressurem    141
# tempm        141
# wspdm        141
# dtype: int64

# %%
data_daily.fillna(data_daily.mean(),inplace=True)
data_daily.isnull().sum()
# Out:
# hum          0
# pressurem    0
# tempm        0
# wspdm        0
# dtype: int64

# %%
data_daily_temp=pd.DataFrame(list(data_daily["tempm"]),columns=["temp"])

# %%
data_daily_temp
# Out:
#            temp
# 0     22.333333
# 1     22.916667
# 2     21.791667
# 3     22.722222
# 4     27.800000
# ...         ...
# 7361  16.850000
# 7362  17.217391
# 7363  15.238095
# 7364  14.095238
# 7365  15.650000
#
# [7366 rows x 1 columns]

# %%
plt.figure(figsize=(20,8))
plt.plot(data_daily_temp)
plt.title("Delhi Temp Variation")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
scaler=MinMaxScaler(feature_range=(-1,1))
data_daily_temp=scaler.fit_transform(data_daily_temp)

# %%
print(data_daily_temp)
print(data_daily_temp.shape)
# Out:
# [[-0.07224714]
#  [-0.0391131 ]
#  [-0.10301445]
#  ...
#  [-0.47526514]
#  [-0.5401808 ]
#  [-0.45186846]]
# (7366, 1)

# %%
steps=30
X_part=[]
Y_part=[]
for i in range(len(data_daily_temp)-steps):
  X_part.append(data_daily_temp[i:i+steps])
  Y_part.append(data_daily_temp[i+steps])

X_part=np.array(X_part)
Y_part=np.array(Y_part)

print(X_part.shape)
print(Y_part.shape)
# Out:
# (7336, 30, 1)
# (7336, 1)

# %%
train_X=X_part[:7000,::]
test_X=X_part[7000:,::]

train_Y=Y_part[:7000]
test_Y=Y_part[7000:]

# %%
from tensorflow.keras import models, layers, utils, optimizers, callbacks
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
model1=models.Sequential()
model1.add(layers.Conv1D(filters=128, kernel_size=2, activation="relu", input_shape=(30,1)))
model1.add(layers.Conv1D(filters=128, kernel_size=2, activation="relu"))
model1.add(layers.MaxPooling1D(pool_size=2))
model1.add(layers.Conv1D(filters=256, kernel_size=2, activation="relu"))
model1.add(layers.Flatten())
model1.add(layers.RepeatVector(30)) #same as input (30,1)
model1.add(layers.LSTM(units=100, return_sequences=True, activation="relu"))
model1.add(layers.Dropout(0.2))
model1.add(layers.LSTM(units=100, return_sequences=True, activation="relu"))
model1.add(layers.Dropout(0.2))
model1.add(layers.Bidirectional(layers.LSTM(units=128, activation="relu")))
model1.add(layers.Dense(100, activation="relu"))
model1.add(layers.Dense(1))

# %%
model1.compile(loss="mae",optimizer=optimizers.Adam(lr=0.0001))
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 29, 128)           384
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 28, 128)           32896
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 14, 128)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 13, 256)           65792
# _________________________________________________________________
# flatten (Flatten)            (None, 3328)              0
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 30, 3328)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 30, 100)           1371600
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 30, 100)           80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 100)           0
# _________________________________________________________________
# bidirectional (Bidirectional (None, 256)               234496
# _________________________________________________________________
# dense (Dense)                (None, 100)               25700
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 1,811,369
# Trainable params: 1,811,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
Earlystp=callbacks.EarlyStopping(monitor="loss", mode="min", patience=5, restore_best_weights=True)
Savemod=callbacks.ModelCheckpoint(filepath="model1_ts.h5", monitor="loss", save_best_only=True)

# %%
history=model1.fit(train_X, train_Y, epochs=200, callbacks=[Earlystp, Savemod])
# Out:
# Epoch 1/200
# 145/219 [==================>...........] - ETA: 1:17 - loss: 0.2343
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-30fe048ecab1> in <module>
# ----> 1 history=model1.fit(train_X, train_Y, epochs=200, callbacks=[Earlystp, Savemod])
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
hist=history.history
train_loss=hist["loss"]
epoch=range(1,len(train_loss)+1)

# %%
plt.plot(epoch,train_loss)

# %%
model1=models.load_model("Models/model1_ts.h5")

# %%
preds=model1.predict(test_X)

# %%
preds=scaler.inverse_transform(preds)

# %%
preds
# Out:
# array([[16.981844],
#        [14.186588],
#        [16.801888],
#        [17.373856],
#        [14.636542],
#        [17.135504],
#        [13.775535],
#        [15.104077],
#        [14.268735],
#        [18.703726],
#        [19.97306 ],
#        [17.591421],
#        [20.662016],
#        [18.973314],
#        [16.867836],
#        [19.580938],
#        [17.668999],
#        [19.7018  ],
#        [20.569063],
#        [21.466738],
#        [20.259987],
#        [18.897594],
#        [21.299444],
#        [21.596642],
#        [20.992414],
#        [21.983646],
#        [23.73166 ],
#        [24.847124],
#        [24.435047],
#        [23.716915],
#        [22.041716],
#        [23.84629 ],
#        [21.523071],
#        [23.22774 ],
#        [25.080868],
#        [23.726534],
#        [23.143394],
#        [23.352999],
#        [25.002262],
#        [24.493202],
#        [25.793056],
#        [24.3434  ],
#        [24.134342],
#        [24.351187],
#        [23.938414],
#        [24.354536],
#        [22.287779],
#        [25.730474],
#        [25.17879 ],
#        [27.75771 ],
#        [28.409288],
#        [26.110254],
#        [25.169361],
#        [25.996305],
#        [26.397501],
#        [29.8691  ],
#        [26.63305 ],
#        [25.613096],
#        [28.667295],
#        [27.834948],
#        [29.234016],
#        [27.808485],
#        [29.59621 ],
#        [30.907133],
#        [31.268108],
#        [30.05386 ],
#        [32.51929 ],
#        [30.815693],
#        [30.902782],
#        [28.028078],
#        [31.972973],
#        [32.465588],
#        [30.856457],
#        [30.584417],
#        [31.48828 ],
#        [32.875534],
#        [33.83863 ],
#        [33.491684],
#        [32.88335 ],
#        [35.25448 ],
#        [33.03932 ],
#        [34.316727],
#        [33.734116],
#        [32.72652 ],
#        [30.368795],
#        [27.693924],
#        [31.686918],
#        [31.497612],
#        [31.063557],
#        [32.99449 ],
#        [33.730766],
#        [34.02182 ],
#        [34.0159  ],
#        [37.29528 ],
#        [36.242798],
#        [34.916763],
#        [30.902306],
#        [28.124989],
#        [32.62715 ],
#        [35.345375],
#        [31.276367],
#        [31.685007],
#        [32.077843],
#        [34.114346],
#        [35.81001 ],
#        [36.290794],
#        [36.093338],
#        [35.30756 ],
#        [37.389004],
#        [36.970665],
#        [35.297607],
#        [36.79594 ],
#        [33.60687 ],
#        [34.749653],
#        [29.546206],
#        [29.695343],
#        [31.993233],
#        [36.89457 ],
#        [36.07942 ],
#        [32.402386],
#        [28.805779],
#        [27.307133],
#        [32.76246 ],
#        [37.35309 ],
#        [36.05022 ],
#        [36.104076],
#        [34.68866 ],
#        [31.722519],
#        [32.580154],
#        [35.256554],
#        [34.01582 ],
#        [34.300274],
#        [34.661102],
#        [32.05034 ],
#        [35.34851 ],
#        [35.524414],
#        [33.326603],
#        [35.705936],
#        [29.098927],
#        [32.777725],
#        [37.251213],
#        [34.017284],
#        [30.182575],
#        [33.573437],
#        [32.978123],
#        [31.145815],
#        [34.209652],
#        [31.752062],
#        [33.32503 ],
#        [32.79652 ],
#        [31.051441],
#        [31.688505],
#        [34.230488],
#        [34.83561 ],
#        [28.309608],
#        [31.269001],
#        [30.701628],
#        [33.723476],
#        [32.124016],
#        [32.804447],
#        [28.503506],
#        [32.512394],
#        [32.37267 ],
#        [31.2298  ],
#        [27.406397],
#        [28.511702],
#        [29.414898],
#        [31.103148],
#        [30.557339],
#        [28.544867],
#        [29.514647],
#        [29.878275],
#        [32.91058 ],
#        [31.778175],
#        [33.76968 ],
#        [31.611359],
#        [30.159597],
#        [32.610462],
#        [29.29143 ],
#        [26.69611 ],
#        [28.520823],
#        [27.99376 ],
#        [28.079075],
#        [28.178547],
#        [28.211136],
#        [28.483206],
#        [31.96196 ],
#        [32.673393],
#        [33.03692 ],
#        [28.684975],
#        [32.641335],
#        [33.121086],
#        [32.709274],
#        [32.93505 ],
#        [28.721058],
#        [28.119694],
#        [31.432774],
#        [29.870127],
#        [31.517859],
#        [30.42081 ],
#        [31.087378],
#        [28.170301],
#        [30.613655],
#        [32.683834],
#        [31.142221],
#        [30.567123],
#        [30.288622],
#        [28.494802],
#        [29.759794],
#        [31.67286 ],
#        [29.64361 ],
#        [32.560352],
#        [27.256985],
#        [30.160088],
#        [28.211063],
#        [29.17306 ],
#        [31.36157 ],
#        [28.867842],
#        [29.771805],
#        [28.892935],
#        [28.565205],
#        [29.972416],
#        [31.098711],
#        [29.634542],
#        [29.46798 ],
#        [28.438557],
#        [31.850811],
#        [30.837193],
#        [30.295792],
#        [32.343117],
#        [30.424765],
#        [31.748291],
#        [31.230774],
#        [31.460974],
#        [32.433083],
#        [33.320374],
#        [29.17771 ],
#        [32.193798],
#        [30.161804],
#        [31.549421],
#        [31.066536],
#        [31.28411 ],
#        [28.917221],
#        [31.54022 ],
#        [31.727703],
#        [32.44082 ],
#        [32.231613],
#        [32.55486 ],
#        [29.77443 ],
#        [27.839354],
#        [29.256605],
#        [30.099428],
#        [30.82365 ],
#        [29.553799],
#        [30.730513],
#        [30.143106],
#        [29.260775],
#        [30.055588],
#        [29.922956],
#        [28.242327],
#        [28.004618],
#        [29.045338],
#        [28.314589],
#        [28.413658],
#        [28.215443],
#        [28.096455],
#        [29.16199 ],
#        [27.78078 ],
#        [28.818956],
#        [27.55661 ],
#        [27.211943],
#        [26.174946],
#        [28.018135],
#        [26.48692 ],
#        [26.32176 ],
#        [24.619186],
#        [24.53143 ],
#        [24.778625],
#        [25.058132],
#        [24.246037],
#        [23.52942 ],
#        [22.95801 ],
#        [23.505844],
#        [23.490492],
#        [23.430271],
#        [22.658821],
#        [23.023664],
#        [22.679789],
#        [23.49168 ],
#        [23.477877],
#        [22.838394],
#        [22.034876],
#        [22.223314],
#        [21.976665],
#        [21.727306],
#        [22.06064 ],
#        [21.877804],
#        [21.201284],
#        [22.11083 ],
#        [21.36154 ],
#        [21.561102],
#        [21.925795],
#        [22.695765],
#        [23.511463],
#        [22.138687],
#        [20.17174 ],
#        [18.981384],
#        [19.766912],
#        [18.649227],
#        [18.880432],
#        [18.078154],
#        [18.362984],
#        [18.288363],
#        [17.790625],
#        [18.954302],
#        [17.862484],
#        [17.448404],
#        [18.564919],
#        [18.178621],
#        [17.971956],
#        [18.759842],
#        [15.126496],
#        [17.0971  ],
#        [17.305044],
#        [16.481747],
#        [18.739967],
#        [17.195786],
#        [18.195608],
#        [16.916134],
#        [15.327493],
#        [14.50223 ],
#        [16.052885],
#        [17.15111 ],
#        [14.735272],
#        [14.487128],
#        [16.564077]], dtype=float32)

# %%
test_Y_inv=scaler.inverse_transform(test_Y)

# %%
scale_factor=0.5
plt.figure(figsize=(20,9))
plt.plot(test_Y_inv ,linewidth=2)
plt.plot(preds,linewidth=3)
ymin,ymax=plt.ylim()
plt.ylim(ymin * scale_factor, ymax)
plt.xlabel("Time", fontsize=20)
plt.ylabel("Temperature (C)", fontsize=20)
plt.legend(('Test','Predicted'))
plt.savefig('Plots/Time_Series_Model.png')
plt.show()

# %%
df = pd.DataFrame({'Real Values':test_Y_inv.reshape(-1), 'Predicted Values':preds.reshape(-1)})
df
# Out:
#      Real Values  Predicted Values
# 0      17.375000         16.981844
# 1      15.846154         14.186588
# 2      15.266667         16.801888
# 3      14.666667         17.373856
# 4      17.250000         14.636542
# ..           ...               ...
# 331    16.850000         16.052885
# 332    17.217391         17.151110
# 333    15.238095         14.735272
# 334    14.095238         14.487128
# 335    15.650000         16.564077
#
# [336 rows x 2 columns]

# %%
mse=mean_squared_error(test_Y_inv,preds)
mae=mean_absolute_error(test_Y_inv,preds)
r2=r2_score(test_Y_inv,preds)
print(f'{mse} {mae} {r2}')
# Out:
# 3.9548396617258392 1.5777395210445402 0.8915861826025074
