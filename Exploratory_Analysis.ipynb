# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
delhi=pd.read_csv("testset.csv")

# %%
delhi
# Out:
#          datetime_utc          _conds  _dewptm  ...  _wgustm  _windchillm  _wspdm
# 0      19961101-11:00           Smoke      9.0  ...      NaN          NaN     7.4
# 1      19961101-12:00           Smoke     10.0  ...      NaN          NaN     NaN
# 2      19961101-13:00           Smoke     11.0  ...      NaN          NaN     NaN
# 3      19961101-14:00           Smoke     10.0  ...      NaN          NaN     NaN
# 4      19961101-16:00           Smoke     11.0  ...      NaN          NaN     0.0
# ...               ...             ...      ...  ...      ...          ...     ...
# 99565  20161231-12:00   Partly Cloudy     15.0  ...      NaN          NaN     7.4
# 99566  20161231-13:00   Partly Cloudy     16.0  ...      NaN          NaN     3.7
# 99567  20161231-15:00             NaN     13.0  ...      NaN          NaN    59.3
# 99568  20161231-18:00  Patches of Fog     12.0  ...      NaN          NaN     0.0
# 99569  20161231-21:00  Patches of Fog     12.0  ...      NaN          NaN     0.0
#
# [99570 rows x 20 columns]

# %%
# delhi.drop(["_precipm",'_pressurem','_heatindexm','_hum','_thunder','_tornado','_vism','_wdird','_wdire','_wgustm','_windchillm','_wspdm'],axis=1,inplace=True)
delhi.head()
# Out:
#      datetime_utc _conds  _dewptm  _fog  ...  _wdire  _wgustm  _windchillm  _wspdm
# 0  19961101-11:00  Smoke      9.0     0  ...    West      NaN          NaN     7.4
# 1  19961101-12:00  Smoke     10.0     0  ...   North      NaN          NaN     NaN
# 2  19961101-13:00  Smoke     11.0     0  ...   North      NaN          NaN     NaN
# 3  19961101-14:00  Smoke     10.0     0  ...   North      NaN          NaN     NaN
# 4  19961101-16:00  Smoke     11.0     0  ...   North      NaN          NaN     0.0
#
# [5 rows x 20 columns]

# %%
delhi['datetime_utc']=pd.to_datetime(delhi['datetime_utc'])
delhi['datetime_utc'].head()
# Out:
# 0   1996-11-01 11:00:00
# 1   1996-11-01 12:00:00
# 2   1996-11-01 13:00:00
# 3   1996-11-01 14:00:00
# 4   1996-11-01 16:00:00
# Name: datetime_utc, dtype: datetime64[ns]

# %%
delhi.describe()
# Out:
#             _dewptm          _fog  ...  _windchillm        _wspdm
# count  98950.000000  99570.000000  ...   573.000000  97212.000000
# mean      15.788388      0.068746  ...     5.708202      7.674429
# std        7.085844      0.253022  ...     1.205967     11.982335
# min      -24.000000      0.000000  ...     2.100000      0.000000
# 25%       10.000000      0.000000  ...     4.900000      0.000000
# 50%       15.000000      0.000000  ...     6.100000      7.400000
# 75%       22.000000      0.000000  ...     6.800000     11.100000
# max       75.000000      1.000000  ...     7.300000   1514.900000
#
# [8 rows x 17 columns]

# %%
delhiplot=delhi[['datetime_utc','_tempm']].copy()
delhiplot['just_date'] = delhiplot['datetime_utc'].dt.date

delhifinal=delhiplot.drop('datetime_utc',axis=1)



delhifinal.set_index('just_date', inplace= True)

delhifinal.head()
# Out:
#             _tempm
# just_date
# 1996-11-01    30.0
# 1996-11-01    28.0
# 1996-11-01    24.0
# 1996-11-01    24.0
# 1996-11-01    23.0

# %%
plt.figure(figsize=(25,8))
plt.plot(delhifinal)
plt.title('Time Series')
plt.xlabel('Date')
plt.ylabel('temperature')
plt.show()

# %%
delhi['_conds'].value_counts(ascending=False)
# Out:
# Haze                             47003
# Smoke                            20551
# Mist                              9104
# Clear                             3129
# Widespread Dust                   2830
# Fog                               2656
# Scattered Clouds                  2197
# Partly Cloudy                     2070
# Shallow Fog                       1860
# Mostly Cloudy                     1520
# Light Rain                        1297
# Partial Fog                       1004
# Patches of Fog                     850
# Thunderstorms and Rain             471
# Heavy Fog                          418
# Light Drizzle                      410
# Rain                               394
# Unknown                            382
# Blowing Sand                       358
# Overcast                           313
# Thunderstorm                       190
# Light Thunderstorms and Rain       170
# Drizzle                            111
# Light Thunderstorm                  63
# Light Fog                           56
# Heavy Rain                          28
# Heavy Thunderstorms and Rain        20
# Thunderstorms with Hail             11
# Squalls                              6
# Light Sandstorm                      6
# Light Rain Showers                   5
# Volcanic Ash                         4
# Light Haze                           4
# Sandstorm                            2
# Funnel Cloud                         2
# Rain Showers                         2
# Light Freezing Rain                  1
# Heavy Thunderstorms with Hail        1
# Light Hail Showers                   1
# Name: _conds, dtype: int64

# %%
plt.figure(figsize=(10, 5));
delhi['_conds'].value_counts().head(10).plot(kind='bar');
plt.title("Top 10 most common weather condition")
plt.ylabel('Days')
plt.xlabel('Weather Conditions')
plt.plot();
plt.savefig("save.png")

# %%
delhi['Date'] = pd.to_datetime(delhi['datetime_utc'])
delhi['year'] = delhi['Date'].dt.year
delhi['month'] = delhi['Date'].dt.month
delhi['day'] = delhi['Date'].dt.day
delhi['hour'] = delhi['Date'].dt.hour

# %%
delhi
# Out:
#              datetime_utc          _conds  _dewptm  ...  month  day  hour
# 0     1996-11-01 11:00:00           Smoke      9.0  ...     11    1    11
# 1     1996-11-01 12:00:00           Smoke     10.0  ...     11    1    12
# 2     1996-11-01 13:00:00           Smoke     11.0  ...     11    1    13
# 3     1996-11-01 14:00:00           Smoke     10.0  ...     11    1    14
# 4     1996-11-01 16:00:00           Smoke     11.0  ...     11    1    16
# ...                   ...             ...      ...  ...    ...  ...   ...
# 99565 2016-12-31 12:00:00   Partly Cloudy     15.0  ...     12   31    12
# 99566 2016-12-31 13:00:00   Partly Cloudy     16.0  ...     12   31    13
# 99567 2016-12-31 15:00:00             NaN     13.0  ...     12   31    15
# 99568 2016-12-31 18:00:00  Patches of Fog     12.0  ...     12   31    18
# 99569 2016-12-31 21:00:00  Patches of Fog     12.0  ...     12   31    21
#
# [99570 rows x 25 columns]

# %%
import scipy.stats

# %%
year_heat = delhi.groupby(delhi.year).mean()
# year_heat._heatindexm.plot(linewidth=1)
df=pd.DataFrame(year_heat._heatindexm)
plt.plot(df.ewm(5).mean())
# pd.ewm(year_humi._hum, 5).plot()
plt.title('Delhi Average Heat by year')
plt.xlabel('year')
plt.savefig('plt_heat.png')

# %%
year_rain = delhi.groupby(delhi.year).mean()
# year_heat._heatindexm.plot(linewidth=1)
df=pd.DataFrame(year_rain._rain)
plt.plot(df.ewm(5).mean())
# pd.ewm(year_humi._hum, 5).plot()
plt.title('Delhi Average Rainfall by year')
plt.xlabel('year')
plt.savefig('plt_rainfall.png')
